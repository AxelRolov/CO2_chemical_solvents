# %% [markdown]
# # Importing libraries

# %%
import sys
from pathlib import Path
import glob
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, r2_score as r2
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import RandomForestRegressor
import pickle
from utils import fragment_control, bounding_box, mkdir

# %% [markdown]
# # Reading descriptors

# %%
desc_dict = {}
for desc in glob.glob('../data/*.csv'):
    desc_dict[Path(desc).stem] = pd.read_csv(desc)

# %% [markdown]
# # Models for the computed rate of reaction (R<sub>QSPR</sub>)

# %% [markdown]
# ## Reading hyperparameters of the best models

# %%
target_col = 'CompRate_ylog'
descs_rf = pd.read_csv('../results/best_hyperparameters/Comprate_best_models_RF.csv')
descs_xgb = pd.read_csv('../results/best_hyperparameters/Comprate_best_models_XGB.csv')

# %%
model_res = desc_dict[descs_rf.loc[0, 'desc_name']].loc[:, ['cid', 'std_smiles', 'CompRate_ylog', 'dG_MD_ylog']]
for desc in descs_xgb['desc_name']:
    model_res[desc + '_XGB'] = None
for desc in descs_rf['desc_name']:
    model_res[desc + '_RF'] = None

# %% [markdown]
# ## Evaluation of the models in 5 times repeated 5-fold CV

# %%
folds_stats = [] # list for saving the stats from CV folds

nspl = 5  # number of folds for CV procedure

nrpts = 5  # number of repeats of CV procedure

kf = RepeatedKFold(n_splits=nspl, n_repeats=nrpts, random_state=0)

i = 0

for train_index, test_index in kf.split(model_res):
   
    y_train = model_res.loc[train_index, f'{target_col}']
    df_temp = model_res.copy(deep=True)
    
    for desc_name in descs_xgb['desc_name']:
        
        X = desc_dict[desc_name].iloc[:, 4:]
        
        xgb_params = eval(descs_xgb.loc[descs_xgb['desc_name']==desc_name, f'{target_col}_param_XGB'].iloc[0])
        xgb_params.update({'n_jobs': -1})
        xgb_model = XGBRegressor(**xgb_params)
        xgb_model.fit(X.loc[train_index], y_train)
        
        df_temp.loc[test_index, f'{desc_name}_XGB'] = xgb_model.predict(X.loc[test_index])
        df_temp.loc[bounding_box(X.loc[train_index], X.loc[test_index]), f'{desc_name}_AD'] = 1   
        df_temp.loc[test_index, 'CV_fold'] = i
        
        q2_proper = r2(model_res.loc[test_index, f'{target_col}'], xgb_model.predict(X.loc[test_index]))
        
        print(f'Method: XGB; Q2: {q2_proper}')
        

    
    for desc_name in descs_rf['desc_name']:
        
        X = desc_dict[desc_name].iloc[:, 4:]
        
        rf_params = eval(descs_rf.loc[descs_rf['desc_name']==desc_name, f'{target_col}_param_RF'].iloc[0])
        rf_params.update({'n_jobs': -1})
        rf_model = RandomForestRegressor(**rf_params)
        rf_model.fit(X.loc[train_index], y_train)
        
        df_temp.loc[test_index, f'{desc_name}_RF'] = rf_model.predict(X.loc[test_index])
        
        q2_proper = r2(model_res.loc[test_index, f'{target_col}'], rf_model.predict(X.loc[test_index]))
        
        print(f'Method: RF; Q2: {q2_proper}')
        
        if desc_name not in descs_xgb['desc_name'].dropna().tolist():
            df_temp.loc[bounding_box(X.loc[train_index], X.loc[test_index]), f'{desc_name}_AD'] = 1
       
    folds_stats.append(df_temp.loc[~df_temp['CV_fold'].isna()])
    i+=1
    print(i)
# Out:
# Method: XGB; Q2: 0.7684492705519271
# Method: XGB; Q2: 0.7134233832856183
# Method: XGB; Q2: 0.7465933923652661
# Method: XGB; Q2: 0.7380599223751063
# Method: XGB; Q2: 0.7353462874594761
# Method: XGB; Q2: 0.7460653548614854
# Method: XGB; Q2: 0.7458821886554599
# Method: XGB; Q2: 0.755824045942479
# Method: XGB; Q2: 0.7555180850918211
# Method: XGB; Q2: 0.7244317213218986
# Method: XGB; Q2: 0.7371188916778156
# Method: XGB; Q2: 0.7682775499047569
# Method: XGB; Q2: 0.7465933923652661
# Method: XGB; Q2: 0.7380599223751063
# Method: XGB; Q2: 0.7458821886554599
# Method: XGB; Q2: 0.755824045942479
# Method: XGB; Q2: 0.7244317213218986
# Method: XGB; Q2: 0.7682775499047569
# Method: RF; Q2: 0.7251103559414466
# Method: RF; Q2: 0.7490344715515559
# Method: RF; Q2: 0.7459310543977968
# Method: RF; Q2: 0.7311034011385729
# Method: RF; Q2: 0.7351675835126779
# Method: RF; Q2: 0.7368445503838703
# Method: RF; Q2: 0.7221354281770525
# Method: RF; Q2: 0.7412376593793054
# Method: RF; Q2: 0.6988062466032786
# Method: RF; Q2: 0.7396424246820329
# Method: RF; Q2: 0.7276363290287322
# Method: RF; Q2: 0.7342367945724245
# Method: RF; Q2: 0.7432234375194123
# Method: RF; Q2: 0.7340936438891179
# Method: RF; Q2: 0.7370513667885233
# Method: RF; Q2: 0.7289372554684908
# Method: RF; Q2: 0.7398047093762408
# Method: RF; Q2: 0.7387378016150479
# 1
# Method: XGB; Q2: 0.6490305066347493
# Method: XGB; Q2: 0.7073294600864319
# Method: XGB; Q2: 0.6603488720106905
# Method: XGB; Q2: 0.730547764275244
# Method: XGB; Q2: 0.6525721011163937
# Method: XGB; Q2: 0.7554039756317938
# Method: XGB; Q2: 0.6591462105210444
# Method: XGB; Q2: 0.6758014963230373
# Method: XGB; Q2: 0.6879814898776722
# Method: XGB; Q2: 0.6640422890756614
# Method: XGB; Q2: 0.6845519598136048
# Method: XGB; Q2: 0.6545761284356062
# Method: XGB; Q2: 0.6603488720106905
# Method: XGB; Q2: 0.730547764275244
# Method: XGB; Q2: 0.6591462105210444
# Method: XGB; Q2: 0.6758014963230373
# Method: XGB; Q2: 0.6640422890756614
# Method: XGB; Q2: 0.6545761284356062
# Method: RF; Q2: 0.6944564612278337
# Method: RF; Q2: 0.6964938195785768
# Method: RF; Q2: 0.6938285179679041
# Method: RF; Q2: 0.6812646095638025
# Method: RF; Q2: 0.6730495265578118
# Method: RF; Q2: 0.6916094231415525
# Method: RF; Q2: 0.6820132564560157
# Method: RF; Q2: 0.6739572365379995
# Method: RF; Q2: 0.6991950672514389
# Method: RF; Q2: 0.6861873253261317
# Method: RF; Q2: 0.7024653901315132
# Method: RF; Q2: 0.681141625791033
# Method: RF; Q2: 0.6749707240898715
# Method: RF; Q2: 0.68276246718899
# Method: RF; Q2: 0.6971311361090636
# Method: RF; Q2: 0.6862824273507098
# Method: RF; Q2: 0.6676516032630964
# Method: RF; Q2: 0.6886480450407768
# 2
# Method: XGB; Q2: 0.4480398862382301
# Method: XGB; Q2: 0.3413470715941048
# Method: XGB; Q2: 0.37282572083192245
# Method: XGB; Q2: 0.36984906187761857
# Method: XGB; Q2: 0.3557269932393441
# Method: XGB; Q2: 0.36289240248177546
# Method: XGB; Q2: 0.3611507800127597
# Method: XGB; Q2: 0.3439587018525121
# Method: XGB; Q2: 0.39572148193619505
# Method: XGB; Q2: 0.3701847204679255
# Method: XGB; Q2: 0.3603943056940674
# Method: XGB; Q2: 0.3998588518898608
# Method: XGB; Q2: 0.37282572083192245
# Method: XGB; Q2: 0.36984906187761857
# Method: XGB; Q2: 0.3611507800127597
# Method: XGB; Q2: 0.3439587018525121
# Method: XGB; Q2: 0.3701847204679255
# Method: XGB; Q2: 0.3998588518898608
# Method: RF; Q2: 0.3513499822675543
# Method: RF; Q2: 0.36373659791063173
# Method: RF; Q2: 0.3787351728164442
# Method: RF; Q2: 0.4823760158130861
# Method: RF; Q2: 0.4515738741675941
# Method: RF; Q2: 0.4645581060363262
# Method: RF; Q2: 0.4447340654226142
# Method: RF; Q2: 0.4261456271437847
# Method: RF; Q2: 0.4698559638588672
# Method: RF; Q2: 0.4972718271855415
# Method: RF; Q2: 0.4429975344103779
# Method: RF; Q2: 0.5124124195531676
# Method: RF; Q2: 0.4487693432051063
# Method: RF; Q2: 0.4613851983628303
# Method: RF; Q2: 0.44629299945444956
# Method: RF; Q2: 0.4664228670286995
# Method: RF; Q2: 0.4950705918241409
# Method: RF; Q2: 0.4406460313661027
# 3
# Method: XGB; Q2: 0.6742372459698298
# Method: XGB; Q2: 0.7268210772608716
# Method: XGB; Q2: 0.724372988417956
# Method: XGB; Q2: 0.7222464328014163
# Method: XGB; Q2: 0.6865865767974451
# Method: XGB; Q2: 0.6816262737671854
# Method: XGB; Q2: 0.7407877940124254
# Method: XGB; Q2: 0.7015025108637869
# Method: XGB; Q2: 0.6840977785248739
# Method: XGB; Q2: 0.6783185719115608
# Method: XGB; Q2: 0.6905788536154089
# Method: XGB; Q2: 0.7107442326298148
# Method: XGB; Q2: 0.724372988417956
# Method: XGB; Q2: 0.7222464328014163
# Method: XGB; Q2: 0.7407877940124254
# Method: XGB; Q2: 0.7015025108637869
# Method: XGB; Q2: 0.6783185719115608
# Method: XGB; Q2: 0.7107442326298148
# Method: RF; Q2: 0.6642561648258485
# Method: RF; Q2: 0.6526521001508876
# Method: RF; Q2: 0.6542314299558434
# Method: RF; Q2: 0.6768658510543109
# Method: RF; Q2: 0.638345679122027
# Method: RF; Q2: 0.6261155763640509
# Method: RF; Q2: 0.6321266585426883
# Method: RF; Q2: 0.6273323870016251
# Method: RF; Q2: 0.6718879543426073
# Method: RF; Q2: 0.6375650298423646
# Method: RF; Q2: 0.6356424989134399
# Method: RF; Q2: 0.6294972185556931
# Method: RF; Q2: 0.623161310413941
# Method: RF; Q2: 0.6126410852631196
# Method: RF; Q2: 0.5861006432508752
# Method: RF; Q2: 0.6385513444536788
# Method: RF; Q2: 0.6381173612428274
# Method: RF; Q2: 0.6172047153832807
# 4
# Method: XGB; Q2: 0.2620976066433175
# Method: XGB; Q2: 0.3431981275700805
# Method: XGB; Q2: 0.2806037876522478
# Method: XGB; Q2: 0.3483738805448853
# Method: XGB; Q2: 0.22117419928581128
# Method: XGB; Q2: 0.2682550430743639
# Method: XGB; Q2: 0.24900042402337264
# Method: XGB; Q2: 0.27158621526191196
# Method: XGB; Q2: 0.27144665104873644
# Method: XGB; Q2: 0.29888148937991554
# Method: XGB; Q2: 0.2683382892627768
# Method: XGB; Q2: 0.3315400505130064
# Method: XGB; Q2: 0.2806037876522478
# Method: XGB; Q2: 0.3483738805448853
# Method: XGB; Q2: 0.24900042402337264
# Method: XGB; Q2: 0.27158621526191196
# Method: XGB; Q2: 0.29888148937991554
# Method: XGB; Q2: 0.3315400505130064
# Method: RF; Q2: 0.3430787015578055
# Method: RF; Q2: 0.3643256883032123
# Method: RF; Q2: 0.3731739805914538
# Method: RF; Q2: 0.3452167592119447
# Method: RF; Q2: 0.34228646425312903
# Method: RF; Q2: 0.370378619738558
# Method: RF; Q2: 0.3339845515716049
# Method: RF; Q2: 0.35442037029782336
# Method: RF; Q2: 0.32476064376436675
# Method: RF; Q2: 0.33256369546541054
# Method: RF; Q2: 0.3443577117043557
# Method: RF; Q2: 0.3302090200336171
# Method: RF; Q2: 0.3502035260679358
# Method: RF; Q2: 0.3527999544173991
# Method: RF; Q2: 0.3450426792767204
# Method: RF; Q2: 0.35663883951558106
# Method: RF; Q2: 0.34793975905069063
# Method: RF; Q2: 0.34684746738500916
# 5
# Method: XGB; Q2: 0.6075196047718925
# Method: XGB; Q2: 0.5494803945241895
# Method: XGB; Q2: 0.5457958197720595
# Method: XGB; Q2: 0.5523018159426452
# Method: XGB; Q2: 0.5639519410691698
# Method: XGB; Q2: 0.5453333579178135
# Method: XGB; Q2: 0.5672593406048037
# Method: XGB; Q2: 0.6354931825980736
# Method: XGB; Q2: 0.6000185039796961
# Method: XGB; Q2: 0.5781057586510159
# Method: XGB; Q2: 0.5836465880421731
# Method: XGB; Q2: 0.5853896270521777
# Method: XGB; Q2: 0.5457958197720595
# Method: XGB; Q2: 0.5523018159426452
# Method: XGB; Q2: 0.5672593406048037
# Method: XGB; Q2: 0.6354931825980736
# Method: XGB; Q2: 0.5781057586510159
# Method: XGB; Q2: 0.5853896270521777
# Method: RF; Q2: 0.5950077721245906
# Method: RF; Q2: 0.6033826545797427
# Method: RF; Q2: 0.6097942799672214
# Method: RF; Q2: 0.6047637189785221
# Method: RF; Q2: 0.6014899430096581
# Method: RF; Q2: 0.602044662797748
# Method: RF; Q2: 0.5756284475723524
# Method: RF; Q2: 0.5720383693808504
# Method: RF; Q2: 0.6288634744883748
# Method: RF; Q2: 0.5922461776417316
# Method: RF; Q2: 0.5988227986707381
# Method: RF; Q2: 0.6042607454789599
# Method: RF; Q2: 0.596702144436958
# Method: RF; Q2: 0.5906035050516085
# Method: RF; Q2: 0.5773264058060379
# Method: RF; Q2: 0.5810504213064392
# Method: RF; Q2: 0.6079209303937245
# Method: RF; Q2: 0.5784826195982301
# 6
# Method: XGB; Q2: 0.35837352118605037
# Method: XGB; Q2: 0.31204902100832654
# Method: XGB; Q2: 0.3429958000982656
# Method: XGB; Q2: 0.2375313697606175
# Method: XGB; Q2: 0.2954960669898693
# Method: XGB; Q2: 0.39861253602794033
# Method: XGB; Q2: 0.31422913659551155
# Method: XGB; Q2: 0.26026211532693855
# Method: XGB; Q2: 0.36811670188836676
# Method: XGB; Q2: 0.34293479818655304
# Method: XGB; Q2: 0.32672323784211066
# Method: XGB; Q2: 0.2681966695710112
# Method: XGB; Q2: 0.3429958000982656
# Method: XGB; Q2: 0.2375313697606175
# Method: XGB; Q2: 0.31422913659551155
# Method: XGB; Q2: 0.26026211532693855
# Method: XGB; Q2: 0.34293479818655304
# Method: XGB; Q2: 0.2681966695710112
# Method: RF; Q2: 0.39671882269726044
# Method: RF; Q2: 0.3749284661893192
# Method: RF; Q2: 0.35532381495144494
# Method: RF; Q2: 0.4026008199944058
# Method: RF; Q2: 0.4334492341690216
# Method: RF; Q2: 0.4292179030751093
# Method: RF; Q2: 0.41760523116265935
# Method: RF; Q2: 0.4016930568301773
# Method: RF; Q2: 0.3829971608004773
# Method: RF; Q2: 0.4146596685026046
# Method: RF; Q2: 0.4001162342884571
# Method: RF; Q2: 0.42866487826530897
# Method: RF; Q2: 0.40733831468396964
# Method: RF; Q2: 0.4075902256690066
# Method: RF; Q2: 0.4342440563722614
# Method: RF; Q2: 0.41685771513788794
# Method: RF; Q2: 0.39675248550933817
# Method: RF; Q2: 0.432122351038586
# 7
# Method: XGB; Q2: 0.6369425107744144
# Method: XGB; Q2: 0.6379714194461281
# Method: XGB; Q2: 0.659019397373213
# Method: XGB; Q2: 0.6900929165542642
# Method: XGB; Q2: 0.6820564423200901
# Method: XGB; Q2: 0.7131111631494955
# Method: XGB; Q2: 0.6583553070141672
# Method: XGB; Q2: 0.6661945537741754
# Method: XGB; Q2: 0.6645833055568522
# Method: XGB; Q2: 0.6702450748024756
# Method: XGB; Q2: 0.6905392213301611
# Method: XGB; Q2: 0.6854767314346069
# Method: XGB; Q2: 0.659019397373213
# Method: XGB; Q2: 0.6900929165542642
# Method: XGB; Q2: 0.6583553070141672
# Method: XGB; Q2: 0.6661945537741754
# Method: XGB; Q2: 0.6702450748024756
# Method: XGB; Q2: 0.6854767314346069
# Method: RF; Q2: 0.6226195445629912
# Method: RF; Q2: 0.6366846771340702
# Method: RF; Q2: 0.6514720420405651
# Method: RF; Q2: 0.6979398248675028
# Method: RF; Q2: 0.7001654958469483
# Method: RF; Q2: 0.6769223416629973
# Method: RF; Q2: 0.6917088156269572
# Method: RF; Q2: 0.7056309023180929
# Method: RF; Q2: 0.6983228533870967
# Method: RF; Q2: 0.7030168315799128
# Method: RF; Q2: 0.6834879075186321
# Method: RF; Q2: 0.7065910002641076
# Method: RF; Q2: 0.6877251736436418
# Method: RF; Q2: 0.6801994702289693
# Method: RF; Q2: 0.6693557342664274
# Method: RF; Q2: 0.6923685849789913
# Method: RF; Q2: 0.6892500738142667
# Method: RF; Q2: 0.699073442942648
# 8
# Method: XGB; Q2: 0.6817345637397894
# Method: XGB; Q2: 0.685720919338913
# Method: XGB; Q2: 0.7152545434981181
# Method: XGB; Q2: 0.7002064808410121
# Method: XGB; Q2: 0.6857785759451314
# Method: XGB; Q2: 0.6600742819490579
# Method: XGB; Q2: 0.7151592509236944
# Method: XGB; Q2: 0.7185494489617903
# Method: XGB; Q2: 0.6708557826656951
# Method: XGB; Q2: 0.703868166336109
# Method: XGB; Q2: 0.6719567399212839
# Method: XGB; Q2: 0.6881827839321979
# Method: XGB; Q2: 0.7152545434981181
# Method: XGB; Q2: 0.7002064808410121
# Method: XGB; Q2: 0.7151592509236944
# Method: XGB; Q2: 0.7185494489617903
# Method: XGB; Q2: 0.703868166336109
# Method: XGB; Q2: 0.6881827839321979
# Method: RF; Q2: 0.6340069310421218
# Method: RF; Q2: 0.5966869450996506
# Method: RF; Q2: 0.6141343449946228
# Method: RF; Q2: 0.6530458581466847
# Method: RF; Q2: 0.6900720806083886
# Method: RF; Q2: 0.6760308649996564
# Method: RF; Q2: 0.6715637042263036
# Method: RF; Q2: 0.6754079453104466
# Method: RF; Q2: 0.6614513996087914
# Method: RF; Q2: 0.6713887284392196
# Method: RF; Q2: 0.6672030849983717
# Method: RF; Q2: 0.6623833840153289
# Method: RF; Q2: 0.666063958978312
# Method: RF; Q2: 0.6619247996460389
# Method: RF; Q2: 0.6796340082648018
# Method: RF; Q2: 0.6492247355794647
# Method: RF; Q2: 0.6875304585809292
# Method: RF; Q2: 0.6705270577760436
# 9
# Method: XGB; Q2: 0.6468116951670015
# Method: XGB; Q2: 0.6385630376497142
# Method: XGB; Q2: 0.6667868288410451
# Method: XGB; Q2: 0.6888109979550245
# Method: XGB; Q2: 0.6387605771375647
# Method: XGB; Q2: 0.6566283301160518
# Method: XGB; Q2: 0.6631649473440115
# Method: XGB; Q2: 0.6553175818934782
# Method: XGB; Q2: 0.6362850978743747
# Method: XGB; Q2: 0.667620858868254
# Method: XGB; Q2: 0.6541972181341107
# Method: XGB; Q2: 0.6142019843577367
# Method: XGB; Q2: 0.6667868288410451
# Method: XGB; Q2: 0.6888109979550245
# Method: XGB; Q2: 0.6631649473440115
# Method: XGB; Q2: 0.6553175818934782
# Method: XGB; Q2: 0.667620858868254
# Method: XGB; Q2: 0.6142019843577367
# Method: RF; Q2: 0.6722641487504074
# Method: RF; Q2: 0.6429521628489437
# Method: RF; Q2: 0.636188431169456
# Method: RF; Q2: 0.6727936122013046
# Method: RF; Q2: 0.6653884510688377
# Method: RF; Q2: 0.6708954196946201
# Method: RF; Q2: 0.6590224131488231
# Method: RF; Q2: 0.665713777958651
# Method: RF; Q2: 0.6535292064390841
# Method: RF; Q2: 0.6582554498488438
# Method: RF; Q2: 0.672515272308591
# Method: RF; Q2: 0.6620048100840406
# Method: RF; Q2: 0.6662311769655787
# Method: RF; Q2: 0.6637166699422234
# Method: RF; Q2: 0.6766230308986825
# Method: RF; Q2: 0.6613547220394012
# Method: RF; Q2: 0.6488326077059244
# Method: RF; Q2: 0.6612826537505514
# 10
# Method: XGB; Q2: 0.6556996079472937
# Method: XGB; Q2: 0.6373696937699587
# Method: XGB; Q2: 0.7052834337962667
# Method: XGB; Q2: 0.6635507414134234
# Method: XGB; Q2: 0.6618823118489213
# Method: XGB; Q2: 0.6293886935337922
# Method: XGB; Q2: 0.6364299464866199
# Method: XGB; Q2: 0.6425830220073496
# Method: XGB; Q2: 0.6774161971294771
# Method: XGB; Q2: 0.6684106803600469
# Method: XGB; Q2: 0.6430631511500394
# Method: XGB; Q2: 0.6723247751741731
# Method: XGB; Q2: 0.7052834337962667
# Method: XGB; Q2: 0.6635507414134234
# Method: XGB; Q2: 0.6364299464866199
# Method: XGB; Q2: 0.6425830220073496
# Method: XGB; Q2: 0.6684106803600469
# Method: XGB; Q2: 0.6723247751741731
# Method: RF; Q2: 0.6576904853202878
# Method: RF; Q2: 0.6241885779149565
# Method: RF; Q2: 0.6356314748127051
# Method: RF; Q2: 0.6705005856699229
# Method: RF; Q2: 0.6883771064284445
# Method: RF; Q2: 0.6824794889654079
# Method: RF; Q2: 0.6760960349376549
# Method: RF; Q2: 0.6726033943909187
# Method: RF; Q2: 0.653022821973049
# Method: RF; Q2: 0.6857770026923562
# Method: RF; Q2: 0.6705555933871563
# Method: RF; Q2: 0.6806122052519687
# Method: RF; Q2: 0.6676749919671205
# Method: RF; Q2: 0.6752792739983882
# Method: RF; Q2: 0.6641387477901133
# Method: RF; Q2: 0.6684426892735438
# Method: RF; Q2: 0.6710689283497095
# Method: RF; Q2: 0.6681472126560124
# 11
# Method: XGB; Q2: 0.5728037019661817
# Method: XGB; Q2: 0.6030299716073864
# Method: XGB; Q2: 0.582063494500414
# Method: XGB; Q2: 0.623383876006127
# Method: XGB; Q2: 0.6334611414979479
# Method: XGB; Q2: 0.6251446835158792
# Method: XGB; Q2: 0.6053725174594227
# Method: XGB; Q2: 0.5933220860960169
# Method: XGB; Q2: 0.6005260606080567
# Method: XGB; Q2: 0.6030657447502297
# Method: XGB; Q2: 0.6287435734455221
# Method: XGB; Q2: 0.6127050601944957
# Method: XGB; Q2: 0.582063494500414
# Method: XGB; Q2: 0.623383876006127
# Method: XGB; Q2: 0.6053725174594227
# Method: XGB; Q2: 0.5933220860960169
# Method: XGB; Q2: 0.6030657447502297
# Method: XGB; Q2: 0.6127050601944957
# Method: RF; Q2: 0.5870284104168834
# Method: RF; Q2: 0.5955684532145922
# Method: RF; Q2: 0.5870803625831585
# Method: RF; Q2: 0.6113296185389381
# Method: RF; Q2: 0.5948885013404022
# Method: RF; Q2: 0.5846368749653106
# Method: RF; Q2: 0.5852887887423216
# Method: RF; Q2: 0.5924998282168278
# Method: RF; Q2: 0.6125139597708045
# Method: RF; Q2: 0.5834586592801848
# Method: RF; Q2: 0.5875791818595804
# Method: RF; Q2: 0.6101901026907126
# Method: RF; Q2: 0.5845400647627361
# Method: RF; Q2: 0.5895889066628102
# Method: RF; Q2: 0.5898348743001565
# Method: RF; Q2: 0.6192944376350988
# Method: RF; Q2: 0.6142370320725437
# Method: RF; Q2: 0.5798951507187917
# 12
# Method: XGB; Q2: 0.6509674320343333
# Method: XGB; Q2: 0.6667319819891041
# Method: XGB; Q2: 0.6788559048262133
# Method: XGB; Q2: 0.7015608404127123
# Method: XGB; Q2: 0.6405844874885032
# Method: XGB; Q2: 0.7100981303610295
# Method: XGB; Q2: 0.6447396686864724
# Method: XGB; Q2: 0.6397815355139644
# Method: XGB; Q2: 0.6648507035070319
# Method: XGB; Q2: 0.6298987711913574
# Method: XGB; Q2: 0.619023560165902
# Method: XGB; Q2: 0.6387050585450489
# Method: XGB; Q2: 0.6788559048262133
# Method: XGB; Q2: 0.7015608404127123
# Method: XGB; Q2: 0.6447396686864724
# Method: XGB; Q2: 0.6397815355139644
# Method: XGB; Q2: 0.6298987711913574
# Method: XGB; Q2: 0.6387050585450489
# Method: RF; Q2: 0.6821622735275028
# Method: RF; Q2: 0.6522498603427485
# Method: RF; Q2: 0.6452650745446791
# Method: RF; Q2: 0.6478156774589516
# Method: RF; Q2: 0.6690520152175212
# Method: RF; Q2: 0.6874889640148405
# Method: RF; Q2: 0.6861346810762494
# Method: RF; Q2: 0.6824348514083991
# Method: RF; Q2: 0.6710839418672512
# Method: RF; Q2: 0.6600117242035453
# Method: RF; Q2: 0.6748396487501803
# Method: RF; Q2: 0.6696334368117463
# Method: RF; Q2: 0.6737652168446806
# Method: RF; Q2: 0.6665901483394848
# Method: RF; Q2: 0.6630033535769655
# Method: RF; Q2: 0.6482490478347052
# Method: RF; Q2: 0.6286926514688279
# Method: RF; Q2: 0.6719145261119334
# 13
# Method: XGB; Q2: 0.3970138480705626
# Method: XGB; Q2: 0.38577180168839176
# Method: XGB; Q2: 0.4028533565939627
# Method: XGB; Q2: 0.4206674220479657
# Method: XGB; Q2: 0.4710964071748266
# Method: XGB; Q2: 0.43844071515502003
# Method: XGB; Q2: 0.43035307192217087
# Method: XGB; Q2: 0.4399102787913737
# Method: XGB; Q2: 0.4615609258307276
# Method: XGB; Q2: 0.45332618300534
# Method: XGB; Q2: 0.40742288177888464
# Method: XGB; Q2: 0.41920626869495003
# Method: XGB; Q2: 0.4028533565939627
# Method: XGB; Q2: 0.4206674220479657
# Method: XGB; Q2: 0.43035307192217087
# Method: XGB; Q2: 0.4399102787913737
# Method: XGB; Q2: 0.45332618300534
# Method: XGB; Q2: 0.41920626869495003
# Method: RF; Q2: 0.6169779965313882
# Method: RF; Q2: 0.546153096759936
# Method: RF; Q2: 0.5577911347250404
# Method: RF; Q2: 0.6002566890252592
# Method: RF; Q2: 0.5671008750562495
# Method: RF; Q2: 0.5561408961005447
# Method: RF; Q2: 0.5587668259079241
# Method: RF; Q2: 0.526469419920756
# Method: RF; Q2: 0.5509948955174446
# Method: RF; Q2: 0.5691074270673178
# Method: RF; Q2: 0.5505748434924467
# Method: RF; Q2: 0.5831085443574602
# Method: RF; Q2: 0.5485534685426466
# Method: RF; Q2: 0.5517060376191333
# Method: RF; Q2: 0.5617283280442132
# Method: RF; Q2: 0.5860958832582654
# Method: RF; Q2: 0.5311057445618844
# Method: RF; Q2: 0.5471192964595741
# 14
# Method: XGB; Q2: 0.5754840599156543
# Method: XGB; Q2: 0.5750142930094713
# Method: XGB; Q2: 0.6115618004595992
# Method: XGB; Q2: 0.6682464859275337
# Method: XGB; Q2: 0.5612129628416
# Method: XGB; Q2: 0.5873659952029273
# Method: XGB; Q2: 0.5779760460137153
# Method: XGB; Q2: 0.5997487581783736
# Method: XGB; Q2: 0.5817420003159014
# Method: XGB; Q2: 0.5857821548788338
# Method: XGB; Q2: 0.5902534598022489
# Method: XGB; Q2: 0.6049949591890709
# Method: XGB; Q2: 0.6115618004595992
# Method: XGB; Q2: 0.6682464859275337
# Method: XGB; Q2: 0.5779760460137153
# Method: XGB; Q2: 0.5997487581783736
# Method: XGB; Q2: 0.5857821548788338
# Method: XGB; Q2: 0.6049949591890709
# Method: RF; Q2: 0.52813905275944
# Method: RF; Q2: 0.526642696993105
# Method: RF; Q2: 0.517509641915006
# Method: RF; Q2: 0.6067558613365092
# Method: RF; Q2: 0.5940793915800564
# Method: RF; Q2: 0.5857005765115403
# Method: RF; Q2: 0.5682037205155358
# Method: RF; Q2: 0.576836737818472
# Method: RF; Q2: 0.6053014346322572
# Method: RF; Q2: 0.5970127510088383
# Method: RF; Q2: 0.6093386998010926
# Method: RF; Q2: 0.5765294998616881
# Method: RF; Q2: 0.5958558010238106
# Method: RF; Q2: 0.5723116002246175
# Method: RF; Q2: 0.5719532874189452
# Method: RF; Q2: 0.5882790858522724
# Method: RF; Q2: 0.5888952688879587
# Method: RF; Q2: 0.5917309507984243
# 15
# Method: XGB; Q2: 0.7333076427233842
# Method: XGB; Q2: 0.7374730607284866
# Method: XGB; Q2: 0.7346996302693121
# Method: XGB; Q2: 0.7336210780409173
# Method: XGB; Q2: 0.7264233915406725
# Method: XGB; Q2: 0.6774614227111415
# Method: XGB; Q2: 0.7277893411204026
# Method: XGB; Q2: 0.7463203249945594
# Method: XGB; Q2: 0.7419401700756993
# Method: XGB; Q2: 0.727586712503336
# Method: XGB; Q2: 0.705466175658428
# Method: XGB; Q2: 0.7450957165769753
# Method: XGB; Q2: 0.7346996302693121
# Method: XGB; Q2: 0.7336210780409173
# Method: XGB; Q2: 0.7277893411204026
# Method: XGB; Q2: 0.7463203249945594
# Method: XGB; Q2: 0.727586712503336
# Method: XGB; Q2: 0.7450957165769753
# Method: RF; Q2: 0.6919900285695166
# Method: RF; Q2: 0.7129759833254607
# Method: RF; Q2: 0.7122864958957049
# Method: RF; Q2: 0.7186940462033624
# Method: RF; Q2: 0.703426408718131
# Method: RF; Q2: 0.705072809609752
# Method: RF; Q2: 0.6955421410107177
# Method: RF; Q2: 0.6956824178969097
# Method: RF; Q2: 0.6835839147029092
# Method: RF; Q2: 0.708144978442824
# Method: RF; Q2: 0.7034687015381207
# Method: RF; Q2: 0.7026476644815491
# Method: RF; Q2: 0.7111307972940439
# Method: RF; Q2: 0.7127998535782485
# Method: RF; Q2: 0.7036917247538671
# Method: RF; Q2: 0.6875321147438631
# Method: RF; Q2: 0.7239726989618727
# Method: RF; Q2: 0.7080396323947893
# 16
# Method: XGB; Q2: 0.5185097186295149
# Method: XGB; Q2: 0.5503713983203902
# Method: XGB; Q2: 0.5259389765323461
# Method: XGB; Q2: 0.6069313225000224
# Method: XGB; Q2: 0.5304395591137224
# Method: XGB; Q2: 0.5993756385152442
# Method: XGB; Q2: 0.542337211833773
# Method: XGB; Q2: 0.5200348377913246
# Method: XGB; Q2: 0.5152986703650071
# Method: XGB; Q2: 0.5430073382214491
# Method: XGB; Q2: 0.5478753679644384
# Method: XGB; Q2: 0.5491056722846352
# Method: XGB; Q2: 0.5259389765323461
# Method: XGB; Q2: 0.6069313225000224
# Method: XGB; Q2: 0.542337211833773
# Method: XGB; Q2: 0.5200348377913246
# Method: XGB; Q2: 0.5430073382214491
# Method: XGB; Q2: 0.5491056722846352
# Method: RF; Q2: 0.6365495046815756
# Method: RF; Q2: 0.6189048201055729
# Method: RF; Q2: 0.6333330886160333
# Method: RF; Q2: 0.5958285198880693
# Method: RF; Q2: 0.6358809105258446
# Method: RF; Q2: 0.6204121743185218
# Method: RF; Q2: 0.6180767798397842
# Method: RF; Q2: 0.6208387413115226
# Method: RF; Q2: 0.6144009754384712
# Method: RF; Q2: 0.6496631597732347
# Method: RF; Q2: 0.6277455872173359
# Method: RF; Q2: 0.6149959918263579
# Method: RF; Q2: 0.613330242214466
# Method: RF; Q2: 0.6224585795010902
# Method: RF; Q2: 0.611720244907618
# Method: RF; Q2: 0.6289606543342008
# Method: RF; Q2: 0.6638674792856617
# Method: RF; Q2: 0.6127915834370378
# 17
# Method: XGB; Q2: 0.753420501536201
# Method: XGB; Q2: 0.7432223640595164
# Method: XGB; Q2: 0.7430851232778228
# Method: XGB; Q2: 0.7760269945690017
# Method: XGB; Q2: 0.7221418458325469
# Method: XGB; Q2: 0.7141909444802774
# Method: XGB; Q2: 0.7732196287549421
# Method: XGB; Q2: 0.7492526608717626
# Method: XGB; Q2: 0.7206165981813495
# Method: XGB; Q2: 0.7187796047747885
# Method: XGB; Q2: 0.7148329116092741
# Method: XGB; Q2: 0.7617362415212006
# Method: XGB; Q2: 0.7430851232778228
# Method: XGB; Q2: 0.7760269945690017
# Method: XGB; Q2: 0.7732196287549421
# Method: XGB; Q2: 0.7492526608717626
# Method: XGB; Q2: 0.7187796047747885
# Method: XGB; Q2: 0.7617362415212006
# Method: RF; Q2: 0.7162734051883938
# Method: RF; Q2: 0.736406516339229
# Method: RF; Q2: 0.7131760098716684
# Method: RF; Q2: 0.7269086755202011
# Method: RF; Q2: 0.7085697505092168
# Method: RF; Q2: 0.7059933680774716
# Method: RF; Q2: 0.6848014697457743
# Method: RF; Q2: 0.6948411393857962
# Method: RF; Q2: 0.7196284140505311
# Method: RF; Q2: 0.6972939023486229
# Method: RF; Q2: 0.6875916542070185
# Method: RF; Q2: 0.7086692604691414
# Method: RF; Q2: 0.7053984587119735
# Method: RF; Q2: 0.6959165228373478
# Method: RF; Q2: 0.6941497700563677
# Method: RF; Q2: 0.7227436603124737
# Method: RF; Q2: 0.707211695313326
# Method: RF; Q2: 0.6907887319092806
# 18
# Method: XGB; Q2: 0.15459763235310486
# Method: XGB; Q2: 0.08893211436907256
# Method: XGB; Q2: 0.12814360543130954
# Method: XGB; Q2: 0.22670374842250385
# Method: XGB; Q2: 0.08871554958212846
# Method: XGB; Q2: 0.1107156002603863
# Method: XGB; Q2: 0.13003527406902116
# Method: XGB; Q2: 0.15834903359986918
# Method: XGB; Q2: 0.13196246471407003
# Method: XGB; Q2: 0.12566505517066684
# Method: XGB; Q2: 0.08966988140974741
# Method: XGB; Q2: 0.15661975822963103
# Method: XGB; Q2: 0.12814360543130954
# Method: XGB; Q2: 0.22670374842250385
# Method: XGB; Q2: 0.13003527406902116
# Method: XGB; Q2: 0.15834903359986918
# Method: XGB; Q2: 0.12566505517066684
# Method: XGB; Q2: 0.15661975822963103
# Method: RF; Q2: 0.22871335843928697
# Method: RF; Q2: 0.2145583846840481
# Method: RF; Q2: 0.25974636456474975
# Method: RF; Q2: 0.25696328126352785
# Method: RF; Q2: 0.24280371417498237
# Method: RF; Q2: 0.27732271214249316
# Method: RF; Q2: 0.2787173965281793
# Method: RF; Q2: 0.26030408572192
# Method: RF; Q2: 0.22128494829361345
# Method: RF; Q2: 0.27160029806887975
# Method: RF; Q2: 0.2633889215302485
# Method: RF; Q2: 0.2515944496140111
# Method: RF; Q2: 0.28535478745112985
# Method: RF; Q2: 0.27200819741331383
# Method: RF; Q2: 0.2805032862188147
# Method: RF; Q2: 0.28313500982199835
# Method: RF; Q2: 0.27034672236102897
# Method: RF; Q2: 0.2738048316580036
# 19
# Method: XGB; Q2: 0.7129105283709278
# Method: XGB; Q2: 0.7042443176076644
# Method: XGB; Q2: 0.7106704476046175
# Method: XGB; Q2: 0.7259561389142068
# Method: XGB; Q2: 0.7202567198480423
# Method: XGB; Q2: 0.734740840056838
# Method: XGB; Q2: 0.7346810666386481
# Method: XGB; Q2: 0.693697322901455
# Method: XGB; Q2: 0.7124093012535819
# Method: XGB; Q2: 0.7298701912495522
# Method: XGB; Q2: 0.70083372517173
# Method: XGB; Q2: 0.7208539013196877
# Method: XGB; Q2: 0.7106704476046175
# Method: XGB; Q2: 0.7259561389142068
# Method: XGB; Q2: 0.7346810666386481
# Method: XGB; Q2: 0.693697322901455
# Method: XGB; Q2: 0.7298701912495522
# Method: XGB; Q2: 0.7208539013196877
# Method: RF; Q2: 0.7197780797742797
# Method: RF; Q2: 0.6603116950483354
# Method: RF; Q2: 0.6724482004541454
# Method: RF; Q2: 0.7361354278794511
# Method: RF; Q2: 0.7244667272146952
# Method: RF; Q2: 0.7322091089823628
# Method: RF; Q2: 0.7328840366302932
# Method: RF; Q2: 0.6992632806613621
# Method: RF; Q2: 0.7379287586393812
# Method: RF; Q2: 0.7190321201918051
# Method: RF; Q2: 0.7227237270814723
# Method: RF; Q2: 0.7306197279161941
# Method: RF; Q2: 0.7162059812772384
# Method: RF; Q2: 0.7343148960050847
# Method: RF; Q2: 0.7239998905613938
# Method: RF; Q2: 0.7107442480661774
# Method: RF; Q2: 0.7219212122185856
# Method: RF; Q2: 0.7195569287067187
# 20
# Method: XGB; Q2: 0.5677887920531561
# Method: XGB; Q2: 0.5858809022032578
# Method: XGB; Q2: 0.6112456390464229
# Method: XGB; Q2: 0.6053385594553602
# Method: XGB; Q2: 0.5981121017315356
# Method: XGB; Q2: 0.638352201020824
# Method: XGB; Q2: 0.5775929972640796
# Method: XGB; Q2: 0.5950590358559236
# Method: XGB; Q2: 0.6061707940971899
# Method: XGB; Q2: 0.571848433003602
# Method: XGB; Q2: 0.6069284387416838
# Method: XGB; Q2: 0.6118271548786867
# Method: XGB; Q2: 0.6112456390464229
# Method: XGB; Q2: 0.6053385594553602
# Method: XGB; Q2: 0.5775929972640796
# Method: XGB; Q2: 0.5950590358559236
# Method: XGB; Q2: 0.571848433003602
# Method: XGB; Q2: 0.6118271548786867
# Method: RF; Q2: 0.6476795704757965
# Method: RF; Q2: 0.6444746539840973
# Method: RF; Q2: 0.6465277912668027
# Method: RF; Q2: 0.658954629903375
# Method: RF; Q2: 0.6288389759558102
# Method: RF; Q2: 0.6531772075158635
# Method: RF; Q2: 0.6466194722812211
# Method: RF; Q2: 0.6493006864323685
# Method: RF; Q2: 0.6173541594598384
# Method: RF; Q2: 0.6279802037070376
# Method: RF; Q2: 0.640356430493356
# Method: RF; Q2: 0.6370902943975378
# Method: RF; Q2: 0.6595124725917398
# Method: RF; Q2: 0.6416000486020936
# Method: RF; Q2: 0.6476349600264981
# Method: RF; Q2: 0.633790604996739
# Method: RF; Q2: 0.6174537908042904
# Method: RF; Q2: 0.6486843083030944
# 21
# Method: XGB; Q2: 0.6755145070690267
# Method: XGB; Q2: 0.686144662914667
# Method: XGB; Q2: 0.6694694436510262
# Method: XGB; Q2: 0.6995174695499068
# Method: XGB; Q2: 0.6739540641515558
# Method: XGB; Q2: 0.6740867899623261
# Method: XGB; Q2: 0.6811832705798102
# Method: XGB; Q2: 0.6746049504148184
# Method: XGB; Q2: 0.682791596652333
# Method: XGB; Q2: 0.6908412773184862
# Method: XGB; Q2: 0.6585738602408959
# Method: XGB; Q2: 0.6619185839343968
# Method: XGB; Q2: 0.6694694436510262
# Method: XGB; Q2: 0.6995174695499068
# Method: XGB; Q2: 0.6811832705798102
# Method: XGB; Q2: 0.6746049504148184
# Method: XGB; Q2: 0.6908412773184862
# Method: XGB; Q2: 0.6619185839343968
# Method: RF; Q2: 0.6739651738543841
# Method: RF; Q2: 0.6745239422170962
# Method: RF; Q2: 0.6610823850650975
# Method: RF; Q2: 0.6947849166605116
# Method: RF; Q2: 0.6912806542501286
# Method: RF; Q2: 0.6873440095209522
# Method: RF; Q2: 0.6918428254557418
# Method: RF; Q2: 0.6870068902907134
# Method: RF; Q2: 0.7089252874904043
# Method: RF; Q2: 0.6888619392894317
# Method: RF; Q2: 0.6926099542677244
# Method: RF; Q2: 0.6896308860464664
# Method: RF; Q2: 0.6767474199079858
# Method: RF; Q2: 0.6954111197525479
# Method: RF; Q2: 0.680373922826925
# Method: RF; Q2: 0.6946667103096023
# Method: RF; Q2: 0.6875588906869299
# Method: RF; Q2: 0.6971767733239363
# 22
# Method: XGB; Q2: 0.6448641669352877
# Method: XGB; Q2: 0.6177829168686981
# Method: XGB; Q2: 0.6228958476038766
# Method: XGB; Q2: 0.6220410024476871
# Method: XGB; Q2: 0.6736222052381765
# Method: XGB; Q2: 0.6669684116651449
# Method: XGB; Q2: 0.5988497281136205
# Method: XGB; Q2: 0.6440720290792148
# Method: XGB; Q2: 0.631442915206598
# Method: XGB; Q2: 0.6390367293014296
# Method: XGB; Q2: 0.6289044124281189
# Method: XGB; Q2: 0.6434680493699374
# Method: XGB; Q2: 0.6228958476038766
# Method: XGB; Q2: 0.6220410024476871
# Method: XGB; Q2: 0.5988497281136205
# Method: XGB; Q2: 0.6440720290792148
# Method: XGB; Q2: 0.6390367293014296
# Method: XGB; Q2: 0.6434680493699374
# Method: RF; Q2: 0.6748998083212068
# Method: RF; Q2: 0.6733998204647313
# Method: RF; Q2: 0.6667172631980998
# Method: RF; Q2: 0.6565959826023253
# Method: RF; Q2: 0.6646245659799271
# Method: RF; Q2: 0.6703076197665241
# Method: RF; Q2: 0.6696147129626104
# Method: RF; Q2: 0.6642914130809716
# Method: RF; Q2: 0.6481357225384354
# Method: RF; Q2: 0.661207823038165
# Method: RF; Q2: 0.660994449120401
# Method: RF; Q2: 0.6712558124975045
# Method: RF; Q2: 0.6736263454701019
# Method: RF; Q2: 0.6690653218655771
# Method: RF; Q2: 0.6548524035440089
# Method: RF; Q2: 0.6602089361445689
# Method: RF; Q2: 0.6641647330123486
# Method: RF; Q2: 0.660357654757723
# 23
# Method: XGB; Q2: 0.5611761884717275
# Method: XGB; Q2: 0.4565055621820572
# Method: XGB; Q2: 0.569277316471149
# Method: XGB; Q2: 0.6163513350045391
# Method: XGB; Q2: 0.5543698681688014
# Method: XGB; Q2: 0.6002954260248583
# Method: XGB; Q2: 0.5437737812345832
# Method: XGB; Q2: 0.618595239769558
# Method: XGB; Q2: 0.5388793066447917
# Method: XGB; Q2: 0.5470649525660067
# Method: XGB; Q2: 0.5440324737775226
# Method: XGB; Q2: 0.5749883690466848
# Method: XGB; Q2: 0.569277316471149
# Method: XGB; Q2: 0.6163513350045391
# Method: XGB; Q2: 0.5437737812345832
# Method: XGB; Q2: 0.618595239769558
# Method: XGB; Q2: 0.5470649525660067
# Method: XGB; Q2: 0.5749883690466848
# Method: RF; Q2: 0.5139942273352869
# Method: RF; Q2: 0.5245066706984733
# Method: RF; Q2: 0.5204707892688947
# Method: RF; Q2: 0.6123721534929355
# Method: RF; Q2: 0.6007256110128016
# Method: RF; Q2: 0.5852829346319168
# Method: RF; Q2: 0.5740028676722762
# Method: RF; Q2: 0.5796875272729065
# Method: RF; Q2: 0.6096160677069614
# Method: RF; Q2: 0.5858596217639866
# Method: RF; Q2: 0.5936114831803962
# Method: RF; Q2: 0.5899477291443443
# Method: RF; Q2: 0.5897247363568758
# Method: RF; Q2: 0.5906288181763075
# Method: RF; Q2: 0.5961314332370388
# Method: RF; Q2: 0.5719288871042403
# Method: RF; Q2: 0.6025667365890495
# Method: RF; Q2: 0.5866529644525804
# 24
# Method: XGB; Q2: 0.7775738319638495
# Method: XGB; Q2: 0.7697331837044232
# Method: XGB; Q2: 0.7607711987713726
# Method: XGB; Q2: 0.7917549777716502
# Method: XGB; Q2: 0.7525119765888669
# Method: XGB; Q2: 0.7362449386101861
# Method: XGB; Q2: 0.7941260645860346
# Method: XGB; Q2: 0.7523014537551368
# Method: XGB; Q2: 0.7610269402443308
# Method: XGB; Q2: 0.7772125396140865
# Method: XGB; Q2: 0.776165912536438
# Method: XGB; Q2: 0.7852341289178401
# Method: XGB; Q2: 0.7607711987713726
# Method: XGB; Q2: 0.7917549777716502
# Method: XGB; Q2: 0.7941260645860346
# Method: XGB; Q2: 0.7523014537551368
# Method: XGB; Q2: 0.7772125396140865
# Method: XGB; Q2: 0.7852341289178401
# Method: RF; Q2: 0.7641113562911472
# Method: RF; Q2: 0.7749981983342207
# Method: RF; Q2: 0.7560620083592176
# Method: RF; Q2: 0.7186992729155683
# Method: RF; Q2: 0.7250686164309255
# Method: RF; Q2: 0.7282133423236372
# Method: RF; Q2: 0.7365847752557892
# Method: RF; Q2: 0.7323064586637724
# Method: RF; Q2: 0.7162930573860951
# Method: RF; Q2: 0.7493215769974864
# Method: RF; Q2: 0.7306923352399504
# Method: RF; Q2: 0.747861253509563
# Method: RF; Q2: 0.735931626527444
# Method: RF; Q2: 0.7346587760461518
# Method: RF; Q2: 0.7194501841262031
# Method: RF; Q2: 0.7166575326123017
# Method: RF; Q2: 0.7391219220250502
# Method: RF; Q2: 0.7347324566141399
# 25

# %%
all_stats = pd.concat(folds_stats, axis=0)  # concatenating the stat data from folds
pred_columns = [col for col in all_stats.columns if '_RF' in col or '_XGB' in col]  # list of columns with predicted values

# %% [markdown]
# ### Consideration of the applicability domain (AD)

# %%
ad_columns = [col for col in all_stats.columns if 'AD' in col]  # list of columns with applicability domain info
all_stats.loc[:, ad_columns] = all_stats.loc[:, ad_columns].fillna(0)  # replace None values with 0
all_stats['applicability_domain'] = None  # column to check whether the compound is in AD
all_stats['applicability_domain_conf'] = None  # for how many models compound is in AD
all_stats['applicability_domain_conf'] = (all_stats.loc[:, ad_columns]==0).astype(int).sum(axis=1)  # sum number of descriptor sets for which compound is in AD
all_stats.loc[all_stats['applicability_domain_conf']>=3, 'applicability_domain'] = 1  # if compound is inside AD for at least 3 descriptor sets => 1
all_stats['applicability_domain'] = all_stats['applicability_domain'].fillna(0)

# %%
all_stats
# Out:
#             cid        std_smiles  CompRate_ylog  dG_MD_ylog IA26AP+OPERA_XGB  \
# 2      100-37-8        CCN(CC)CCO      -0.684356   -1.806987        -0.536577
# 7     7005-47-2    CN(C)C(C)(C)CO      -0.396975   -1.779119        -0.546219
# 8    19059-68-8   CN(C)CC(C)(C)CO      -0.356186   -1.761684         -0.49872
# 10     139-87-7       CCN(CCO)CCO      -0.176428   -1.720622        -0.230906
# 16    2955-88-6        OCCN1CCCC1      -0.679613   -1.801336        -0.591066
# ..          ...               ...            ...         ...              ...
# 116  59941-12-7   CCCCCC1CCCN1CCO      -0.382947   -1.760751        -0.232163
# 117  64897-89-8  CC(C)CCN(CCO)CCO      -0.366887   -1.760357        -0.345632
# 118  40694-17-5     CN(CCO)CCCCCO      -0.379963   -1.769528        -0.600749
# 119    102-81-8    CCCCN(CCO)CCCC      -0.549957   -1.799773        -0.480979
# 122  19031-93-7      CCCN(CCS)CCS      -0.412004   -1.780960        -0.485341
#
#     IIAB13+OPERA_XGB IIRA13+OPERA_XGB IIRA14+OPERA_XGB IIRA14P+OPERA_XGB  \
# 2          -0.552883        -0.523912        -0.538123         -0.543032
# 7          -0.467214        -0.512419        -0.452513         -0.529866
# 8          -0.551612        -0.516388         -0.52264         -0.525994
# 10         -0.244749         -0.21171        -0.256978         -0.232602
# 16          -0.58478        -0.537137        -0.583798         -0.558821
# ..               ...              ...              ...               ...
# 116        -0.281058         -0.29106         -0.22265          -0.24732
# 117        -0.348134        -0.334635         -0.37313         -0.385786
# 118        -0.603915        -0.635035        -0.542838          -0.57967
# 119        -0.476299        -0.477567        -0.480391         -0.517371
# 122        -0.504678        -0.452462        -0.504482         -0.489437
#
#     IIRA15P+OPERA_XGB  ... IIRAB26+OPERA_AD IA36AP+OPERA_AD IAB26AP+OPERA_AD  \
# 2           -0.541948  ...              0.0             0.0              0.0
# 7            -0.50461  ...              1.0             1.0              1.0
# 8           -0.585314  ...              0.0             0.0              0.0
# 10          -0.238692  ...              0.0             0.0              0.0
# 16          -0.614406  ...              0.0             0.0              0.0
# ..                ...  ...              ...             ...              ...
# 116         -0.235897  ...              1.0             0.0              0.0
# 117         -0.331456  ...              0.0             0.0              0.0
# 118         -0.603301  ...              1.0             0.0              0.0
# 119          -0.42841  ...              1.0             1.0              1.0
# 122         -0.486508  ...              1.0             1.0              1.0
#
#     IIRA15+OPERA_AD IIRA16+OPERA_AD IIRA17+OPERA_AD IIRAB15+OPERA_AD  \
# 2               0.0             0.0             0.0              0.0
# 7               1.0             1.0             1.0              1.0
# 8               0.0             0.0             0.0              0.0
# 10              0.0             0.0             0.0              0.0
# 16              0.0             0.0             0.0              0.0
# ..              ...             ...             ...              ...
# 116             1.0             1.0             1.0              1.0
# 117             0.0             0.0             0.0              0.0
# 118             1.0             1.0             1.0              1.0
# 119             1.0             1.0             1.0              1.0
# 122             1.0             1.0             1.0              1.0
#
#     IIRAB17+OPERA_AD applicability_domain applicability_domain_conf
# 2                0.0                    1                        25
# 7                1.0                    0                         0
# 8                0.0                    1                        25
# 10               0.0                    1                        25
# 16               0.0                    1                        25
# ..               ...                  ...                       ...
# 116              1.0                    1                        16
# 117              0.0                    1                        25
# 118              1.0                    1                        16
# 119              1.0                    0                         0
# 122              1.0                    0                         0
#
# [620 rows x 68 columns]

# %%
all_stats.groupby('cid')['applicability_domain'].mean().value_counts()  # how many compounds are outside AD in CV procedure?
# Out:
# 1.0    86
# 0.0    28
# 0.6     6
# 0.8     3
# 0.4     1
# Name: applicability_domain, dtype: int64

# %%
all_stats_temp = all_stats.copy(deep=True)  # create a temporary dataframe for aggregation of predictions cosnidering AD
for col in ad_columns:
    all_stats_temp.loc[all_stats_temp[col]==1, [coli for coli in all_stats_temp.columns if col.replace('_AD', '_RF') in coli or col.replace('_AD', '_XGB') in coli]] = None
all_stats_temp['avg_pred'] = all_stats_temp.loc[:, pred_columns].median(axis=1)
all_stats.loc[:, 'avg_pred'] = all_stats_temp['avg_pred']
all_stats.loc[:, 'avg_pred_AD'] = all_stats_temp['avg_pred']
all_stats.loc[all_stats['avg_pred_AD'].isna(), 'avg_pred'] = all_stats.loc[all_stats['avg_pred_AD'].isna(), pred_columns].median(axis=1)

# %%
all_stats
# Out:
#             cid        std_smiles  CompRate_ylog  dG_MD_ylog IA26AP+OPERA_XGB  \
# 2      100-37-8        CCN(CC)CCO      -0.684356   -1.806987        -0.536577
# 7     7005-47-2    CN(C)C(C)(C)CO      -0.396975   -1.779119        -0.546219
# 8    19059-68-8   CN(C)CC(C)(C)CO      -0.356186   -1.761684         -0.49872
# 10     139-87-7       CCN(CCO)CCO      -0.176428   -1.720622        -0.230906
# 16    2955-88-6        OCCN1CCCC1      -0.679613   -1.801336        -0.591066
# ..          ...               ...            ...         ...              ...
# 116  59941-12-7   CCCCCC1CCCN1CCO      -0.382947   -1.760751        -0.232163
# 117  64897-89-8  CC(C)CCN(CCO)CCO      -0.366887   -1.760357        -0.345632
# 118  40694-17-5     CN(CCO)CCCCCO      -0.379963   -1.769528        -0.600749
# 119    102-81-8    CCCCN(CCO)CCCC      -0.549957   -1.799773        -0.480979
# 122  19031-93-7      CCCN(CCS)CCS      -0.412004   -1.780960        -0.485341
#
#     IIAB13+OPERA_XGB IIRA13+OPERA_XGB IIRA14+OPERA_XGB IIRA14P+OPERA_XGB  \
# 2          -0.552883        -0.523912        -0.538123         -0.543032
# 7          -0.467214        -0.512419        -0.452513         -0.529866
# 8          -0.551612        -0.516388         -0.52264         -0.525994
# 10         -0.244749         -0.21171        -0.256978         -0.232602
# 16          -0.58478        -0.537137        -0.583798         -0.558821
# ..               ...              ...              ...               ...
# 116        -0.281058         -0.29106         -0.22265          -0.24732
# 117        -0.348134        -0.334635         -0.37313         -0.385786
# 118        -0.603915        -0.635035        -0.542838          -0.57967
# 119        -0.476299        -0.477567        -0.480391         -0.517371
# 122        -0.504678        -0.452462        -0.504482         -0.489437
#
#     IIRA15P+OPERA_XGB  ... IAB26AP+OPERA_AD IIRA15+OPERA_AD IIRA16+OPERA_AD  \
# 2           -0.541948  ...              0.0             0.0             0.0
# 7            -0.50461  ...              1.0             1.0             1.0
# 8           -0.585314  ...              0.0             0.0             0.0
# 10          -0.238692  ...              0.0             0.0             0.0
# 16          -0.614406  ...              0.0             0.0             0.0
# ..                ...  ...              ...             ...             ...
# 116         -0.235897  ...              0.0             1.0             1.0
# 117         -0.331456  ...              0.0             0.0             0.0
# 118         -0.603301  ...              0.0             1.0             1.0
# 119          -0.42841  ...              1.0             1.0             1.0
# 122         -0.486508  ...              1.0             1.0             1.0
#
#     IIRA17+OPERA_AD IIRAB15+OPERA_AD IIRAB17+OPERA_AD applicability_domain  \
# 2               0.0              0.0              0.0                    1
# 7               1.0              1.0              1.0                    0
# 8               0.0              0.0              0.0                    1
# 10              0.0              0.0              0.0                    1
# 16              0.0              0.0              0.0                    1
# ..              ...              ...              ...                  ...
# 116             1.0              1.0              1.0                    1
# 117             0.0              0.0              0.0                    1
# 118             1.0              1.0              1.0                    1
# 119             1.0              1.0              1.0                    0
# 122             1.0              1.0              1.0                    0
#
#     applicability_domain_conf  avg_pred avg_pred_AD
# 2                          25 -0.548086   -0.548086
# 7                           0 -0.526532         NaN
# 8                          25 -0.524433   -0.524433
# 10                         25 -0.245284   -0.245284
# 16                         25 -0.574516   -0.574516
# ..                        ...       ...         ...
# 116                        16 -0.274997   -0.274997
# 117                        25 -0.334635   -0.334635
# 118                        16 -0.593111   -0.593111
# 119                         0 -0.526468         NaN
# 122                         0 -0.521818         NaN
#
# [620 rows x 70 columns]

# %% [markdown]
# ### Showing stats obtained in 5x5 CV

# %%
q2_cv = []
mae_cv = []
rmse_cv = []
all_stats_res = []
for cv_fold in range(0, nspl*nrpts, nspl):
    if cv_fold == 0:
        all_stats_res.append(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), ['cid', 'avg_pred']])
    else:
        all_stats_res.append(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), ['avg_pred']])
    q2_cv.append(r2(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [f'{target_col}']], all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), ['avg_pred']]))
    rmse_cv.append(mse(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [f'{target_col}']], all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), ['avg_pred']])**0.5)             
    mae_cv.append(mae(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [f'{target_col}']], all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), ['avg_pred']]))

# %%
q2_cv = []
mae_cv = []
rmse_cv = []
all_stats_res = []
for col in pred_columns:
    q2_cv = []
    mae_cv = []
    rmse_cv = []
    all_stats_res = []
    for cv_fold in range(0, nspl*nrpts, nspl):
        if cv_fold == 0:
            all_stats_res.append(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), ['cid', col]])
        else:
            all_stats_res.append(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [col]])
        q2_cv.append(r2(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [f'{target_col}']], all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [col]]))
        rmse_cv.append(mse(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [f'{target_col}']], all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [col]])**0.5)             
        mae_cv.append(mae(all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [f'{target_col}']], all_stats.loc[all_stats['CV_fold'].isin([i for i in range(cv_fold, cv_fold+nspl)]), [col]]))                         
    print(f'Gas: {target_col}; {col} Q2(5x5CV): {round(np.mean(q2_cv), 2)}; Q2_std(5x5CV): {round(np.std(q2_cv), 2)}')
    print(f'Gas: {target_col}; {col} RMSE(5x5CV): {round(np.mean(rmse_cv), 2)}; RMSE_std(5x5CV): {round(np.std(rmse_cv), 3)}')
    print(f'Gas: {target_col}; {col} MAE(5x5CV): {round(np.mean(mae_cv), 2)}; MAE_std(5x5CV): {round(np.std(mae_cv), 3)}')
# Out:
# Gas: CompRate_ylog; IA26AP+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IA26AP+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IA26AP+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIAB13+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIAB13+OPERA_XGB RMSE(5x5CV): 0.16; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIAB13+OPERA_XGB MAE(5x5CV): 0.13; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA13+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA13+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA13+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA14+OPERA_XGB Q2(5x5CV): 0.65; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA14+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRA14+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRA14P+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA14P+OPERA_XGB RMSE(5x5CV): 0.16; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRA14P+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA15P+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA15P+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRA15P+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA23+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA23+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA23+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA24+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA24+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRA24+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA24P+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA24P+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA24P+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA25+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA25+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA25+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA25P+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA25P+OPERA_XGB RMSE(5x5CV): 0.16; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA25P+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA26+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA26+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRA26+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB13+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRAB13+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB13+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRAB14+OPERA_XGB Q2(5x5CV): 0.65; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB14+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRAB14+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRAB23+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRAB23+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB23+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRAB24+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB24+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRAB24+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB25+OPERA_XGB Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRAB25+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB25+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRAB26+OPERA_XGB Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB26+OPERA_XGB RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRAB26+OPERA_XGB MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IA26AP+OPERA_RF Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IA26AP+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IA26AP+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IA36AP+OPERA_RF Q2(5x5CV): 0.62; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IA36AP+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.005
# Gas: CompRate_ylog; IA36AP+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IAB26AP+OPERA_RF Q2(5x5CV): 0.63; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IAB26AP+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IAB26AP+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA13+OPERA_RF Q2(5x5CV): 0.65; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA13+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA13+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA14+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA14+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA14+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA15+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA15+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA15+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA16+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA16+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRA16+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA17+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA17+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA17+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA23+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA23+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA23+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA24+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRA24+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA24+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRA25+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRA25+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRA25+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB13+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB13+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB13+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRAB14+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB14+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRAB14+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB15+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB15+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRAB15+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB17+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB17+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB17+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRAB23+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; IIRAB23+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB23+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002
# Gas: CompRate_ylog; IIRAB24+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB24+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB24+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003
# Gas: CompRate_ylog; IIRAB25+OPERA_RF Q2(5x5CV): 0.64; Q2_std(5x5CV): 0.02
# Gas: CompRate_ylog; IIRAB25+OPERA_RF RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.004
# Gas: CompRate_ylog; IIRAB25+OPERA_RF MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.003

# %%
print(f'Gas: {target_col}; Q2(5x5CV): {round(np.mean(q2_cv), 3)}; Q2_std(5x5CV): {round(np.std(q2_cv), 2)}')
print(f'Gas: {target_col}; RMSE(5x5CV): {round(np.mean(rmse_cv), 2)}; RMSE_std(5x5CV): {round(np.std(rmse_cv), 3)}')
print(f'Gas: {target_col}; MAE(5x5CV): {round(np.mean(mae_cv), 2)}; MAE_std(5x5CV): {round(np.std(mae_cv), 3)}')
# Out:
# Gas: CompRate_ylog; Q2(5x5CV): 0.645; Q2_std(5x5CV): 0.01
# Gas: CompRate_ylog; RMSE(5x5CV): 0.15; RMSE_std(5x5CV): 0.003
# Gas: CompRate_ylog; MAE(5x5CV): 0.12; MAE_std(5x5CV): 0.002

# %% [markdown]
# ### Analyzing outliers

# %%
rmse_cv = np.mean(rmse_cv)  # the value of rmse from CV for outlier analysis

# %%
all_stats_res = pd.concat(all_stats_res, axis=1)
all_stats_res = pd.merge(all_stats_res, model_res.loc[:, ['cid', f'{target_col}']], on='cid', how='left')
all_stats_res.loc[:, 'avg_pred_fin'] = all_stats_res.loc[:, ['avg_pred']].mean(axis=1)
all_stats_res['abs_err'] = all_stats_res.loc[:, 'avg_pred_fin'] - all_stats_res.loc[:, f'{target_col}']
all_stats_res['abs_err'] = all_stats_res['abs_err'].abs()

# %%
all_stats_res.loc[all_stats_res['abs_err']>=2*rmse_cv, 'outlier'] = 1

# %% [markdown]
# ### Saving the dataframe with stats for the figure

# %% [raw]
# all_stats_res.to_csv('../results/model_stats/CompRate_5x5CV_stats.csv', index=False)

# %% [markdown]
# ## (re)Fitting and saving the models

# %%
y = model_res.loc[:, f'{target_col}']
for desc_name in descs_xgb['desc_name']:
    X = desc_dict[desc_name].iloc[:, 4:]
    xgb_params = eval(descs_xgb.loc[descs_xgb['desc_name']==desc_name, f'{target_col}_param_XGB'].iloc[0])
    xgb_params.update({'n_jobs': -1})
    xgb_model = XGBRegressor(**xgb_params)
    xgb_model.fit(X, y)
    with open(f'../results/models/comprate/Comprate_{desc_name}_xgb.pkl', 'wb') as mf:
        pickle.dump(xgb_model, mf)
for desc_name in descs_rf['desc_name']:
    X = desc_dict[desc_name].iloc[:, 4:]
    rf_params = eval(descs_rf.loc[descs_rf['desc_name']==desc_name, f'{target_col}_param_RF'].iloc[0])
    rf_params.update({'n_jobs': -1})
    rf_model = RandomForestRegressor(**rf_params)
    rf_model.fit(X, y)
    with open(f'../results/models/comprate/Comprate_{desc_name}_rf.pkl', 'wb') as mf:
        pickle.dump(rf_model, mf)
